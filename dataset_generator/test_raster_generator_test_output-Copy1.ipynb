# %%
#import warnings
#warnings.filterwarnings('ignore')

import datacube

import matplotlib.pyplot as plt
import matplotlib.cm as color_maps  
from matplotlib.pyplot import figure, cm

import json
import time
import sys
import os

import rasterio
import rasterio.mask
from rasterio.warp import calculate_default_transform, reproject, Resampling
from rasterio.merge import merge
from rasterio.plot import show

import rioxarray as rio

import xarray as xr
import numpy as np
import pandas as pd
import geopandas as gpd
from osgeo import ogr, gdal

from datetime import datetime
#from time import time

import skimage
from skimage import exposure
from skimage import morphology
from skimage.morphology import disk
from skimage.morphology import rectangle
from skimage.filters import rank

import glob
import fiona
import subprocess

import utils.data_cube_utilities.dc_utilities as utils
from utils.data_cube_utilities.data_access_api import DataAccessApi
from utils.data_cube_utilities.dc_utilities import write_geotiff_from_xr, write_png_from_xr
from utils.data_cube_utilities.dc_chunker import create_geographic_chunks, combine_geographic_chunks
from utils.data_cube_utilities.dc_mosaic import create_median_mosaic, create_mosaic
from utils.data_cube_utilities.dc_sar_utils import dn_to_db 

from rmmeh.vanilla import rmmeh

# %%
def rasterization(InputVector,OutputImage,RefImage):
    gdalformat = 'GTiff'
    datatype = gdal.GDT_Byte
    burnVal = 1 #value for the output image pixels
    ##########################################################
    # Get projection info from reference image
    Image = gdal.Open(RefImage, gdal.GA_ReadOnly)
    print(Image)

    # Open Shapefile
    Shapefile = ogr.Open(InputVector)
    Shapefile_layer = Shapefile.GetLayer()

    # Rasterising
    print("Rasterising shapefile...")
    Output = gdal.GetDriverByName(gdalformat).Create(OutputImage, Image.RasterXSize, Image.RasterYSize, 1, datatype, options=['COMPRESS=DEFLATE'])
    Output.SetProjection(Image.GetProjectionRef())
    Output.SetGeoTransform(Image.GetGeoTransform()) 

    # Write data to band 1
    Band = Output.GetRasterBand(1)
    Band.SetNoDataValue(0)
    gdal.RasterizeLayer(Output, [1], Shapefile_layer, burn_values=[burnVal])

    # Close datasets
    Band = None
    Output = None
    Image = None
    Shapefile = None

    # Build image overviews
    subprocess.call("gdaladdo --config COMPRESS_OVERVIEW DEFLATE "+OutputImage+" 2 4 8 16 32 64", shell=True)


    print("Done.")

    print('finist_rasterise_vector')
    
def rgb(dataset, bands = ['nir', 'red', 'green'], paint_on_mask = []):
    
    fig=plt.figure()
    fig.set_size_inches(9, 9)
    
    rgb = np.stack([dataset[bands[0]], dataset[bands[1]], dataset[bands[2]]], axis = -1)
    rgb = rgb.astype(np.float32)

    p2, p98 = np.percentile(rgb, (2, 98))
    rgb = exposure.rescale_intensity(rgb, in_range=(p2, p98)) * 255.0

    rgb = rgb.astype(int) 

    for mask, color in paint_on_mask:        
        rgb[mask] = np.array([256,256,256]) - np.array(color).astype(np.int16)
    plt.imshow(rgb)
        
def generate_cloud_mask(dataset, include_shadows = False):
    #Create boolean Masks for clear and water pixels
      
    clear_pixels = dataset.pixel_qa.values == (2 ) 
    water_pixels = dataset.pixel_qa.values == (4 )
    shadow_pixels= dataset.pixel_qa.values == (3 )
           
    #a_clean_mask = np.logical_or(clear_pixels, water_pixels)
    a_clean_mask = np.logical_or(1, 1)
    if include_shadows:
        a_clean_mask = np.logical_or(a_clean_mask, shadow_pixels)
        
    return np.invert(a_clean_mask)

def mrf_mosaic(dataset):
    # The mask here is based on pixel_qa products. It comes bundled in with most Landsat Products.
    cloud_free_boolean_mask = np.invert(generate_cloud_mask(dataset))
    #cloud_free_boolean_mask = generate_cloud_mask(dataset)
    return create_mosaic(dataset, clean_mask = cloud_free_boolean_mask)

# %% [markdown]
# ## 1. Initialization

# %%
sugarcane_shp = './shp/clipped_sugarcane.shp'
rice_shp = './shp/clipped_rice.shp'

longitude_extents = (99.6901, 99.7776)
latitude_extents = (16.5625, 16.4874)

#99.6910 16.6525
#99.7776 16.4874

platform = "SENTINEL_2_Thailand"
product = "s2_level2a_Thailand"
                      
bands = ['coastal', 
         'blue', 'green', 'red', 
         #'veg5', 'veg6', 'veg7', 
         'nir', 'narrow_nir', 
         #'water_vapour', 'swir1', 'swir2', 
         'AOT', 'pixel_qa']
         #'SCL', 'WVP', 'AOT', 'pixel_qa']

dc = datacube.Datacube(app = 'my_app', config = '/home/ubuntu/.datacubeThailandS2.conf')

time_extents = ('2019-05-01', '2021-05-31')
#time_extents = ('2020-01-01', '2021-05-31')

n_sample = 10000
safety_factor = 1.5

result_file = ("x_train", "y_train")

# %% [markdown]
# ## 2. Get sentinel2 data from ODC as the same size and resolution of input raster

# %%
start_time = time.time()
print("Mem status before loading dataset")
# !cat /proc/meminfo | grep Mem

s2_dataset = dc.load(latitude = latitude_extents,
                     longitude = longitude_extents,
                     #latitude = (latitude_extents[0], midpoint[0]),
                     #longitude = (longitude_extents[0], midpoint[1]),
                     platform = platform,
                     time = time_extents,
                     product = product,
                     measurements = bands)

print("loading time:", time.time() - start_time,"Sec.")

print("Mem status after dataset loaded")
# !cat /proc/meminfo | grep Mem
# Out:
# Mem status before loading dataset
# MemTotal:       132028380 kB
# MemFree:        62916240 kB
# MemAvailable:   94424884 kB
# loading time: 58.59607744216919 Sec.
# Mem status after dataset loaded
# MemTotal:       132028380 kB
# MemFree:        60986388 kB
# MemAvailable:   92494032 kB

# %%
#s2_dataset.to_netcdf("odc_on_disk.nc")

s2_dataset
# Out:
# <xarray.Dataset>
# Dimensions:     (latitude: 812, longitude: 946, time: 155)
# Coordinates:
#   * time        (time) datetime64[ns] 2019-05-05T04:03:48.860000 ... 2021-05-29T04:03:41.640000
#   * latitude    (latitude) float64 16.56 16.56 16.56 16.56 ... 16.49 16.49 16.49
#   * longitude   (longitude) float64 99.69 99.69 99.69 ... 99.78 99.78 99.78
# Data variables:
#     coastal     (time, latitude, longitude) int16 780 780 780 ... 13282 13282
#     blue        (time, latitude, longitude) int16 1020 1010 963 ... 13512 13288
#     green       (time, latitude, longitude) int16 1482 1488 1428 ... 12536 12176
#     red         (time, latitude, longitude) int16 1502 1494 1446 ... 11832 11736
#     nir         (time, latitude, longitude) int16 3544 3572 3686 ... 10928 10672
#     narrow_nir  (time, latitude, longitude) int16 3908 3908 4048 ... 11405 11405
#     AOT         (time, latitude, longitude) int16 456 456 456 ... 204 204 204
#     pixel_qa    (time, latitude, longitude) int16 5 5 5 5 4 4 4 ... 9 9 9 9 9 9
# Attributes:
#     crs:      EPSG:4326

# %%
s2_mosaic=mrf_mosaic(s2_dataset)
s2_mosaic

#draw image
rgb(s2_mosaic, bands=['red','green','blue'])

#save mosaic to GeoTIFF and will be use as RefImage 
measurements = ['red', 'green', 'blue']
RefImage = './refImage2.tif'
write_geotiff_from_xr(RefImage, s2_mosaic, measurements)

# %%
#Image area in sq.km.
1652*1317*(100)/(1000*1000)
# Out:
# 217.5684

# %% [markdown]
# ## 1. read shape file

# %%
def records(file):  
    # generator 
    reader = ogr.Open(file)
    layer = reader.GetLayer(0)
    result = []
    for i in range(layer.GetFeatureCount()):
        feature = layer.GetFeature(i)
        polygon = json.loads(feature.ExportToJson())
        geojson = json.dumps(polygon['geometry'])
        tmp_polygon = ogr.CreateGeometryFromJson(geojson)
        result.append(tmp_polygon)
    return result
        
def in_polygon(lat, lon, shp_records):
    point = ogr.Geometry(ogr.wkbPoint)
    point.AddPoint(lon, lat)

    for i, polygon in enumerate(shp_records):
        if point.Within(polygon):
            return True
        
    return False

# %%
sugarcane_area = records(sugarcane_shp)
rice_area = records(rice_shp)

# %%
#try in-polygon test
sugar_point = (16.4006, 99.7045)
rice_point = (16.3647, 99.6797)

print("is sugar_point in sugar_area", in_polygon(sugar_point[0], sugar_point[1], sugarcane_area))
print("is sugar_point in rice_area", in_polygon(sugar_point[0], sugar_point[1], rice_area))
print("is rice_point in sugar_area", in_polygon(rice_point[0], rice_point[1], sugarcane_area))
print("is rice_point in rice_area", in_polygon(rice_point[0], rice_point[1], rice_area))
# Out:
# is sugar_point in sugar_area True
# is sugar_point in rice_area False
# is rice_point in sugar_area False
# is rice_point in rice_area True

# %% [markdown]
# ### Create Raster

# %%
InputVector = sugarcane_shp
OutputImage = 'clipped_sugarcane2.tif'
rasterization(InputVector,OutputImage,RefImage)
# Out:
# <osgeo.gdal.Dataset; proxy of <Swig Object of type 'GDALDatasetShadow *' at 0x7f46d1139600> >
# Rasterising shapefile...
# Done.
# finist_rasterise_vector

# %%
InputVector = rice_shp
OutputImage = 'clipped_rice2.tif'
rasterization(InputVector,OutputImage,RefImage)
# Out:
# <osgeo.gdal.Dataset; proxy of <Swig Object of type 'GDALDatasetShadow *' at 0x7f46d11392d0> >
# Rasterising shapefile...
# Done.
# finist_rasterise_vector

# %% [markdown]
# ## 3. Sampling locations from (1.)

# %%
print(len(s2_dataset.latitude.data), len(s2_dataset.longitude.data))
# Out:
# 812 946

# %%
real_sugar = rasterio.open('clipped_sugarcane2.tif')
real_rice = rasterio.open('clipped_rice2.tif')
print(real_sugar.height, real_sugar.width)

sugar_pix = real_sugar.read(1)
rice_pix = real_rice.read(1)
# Out:
# 812 946

# %% [markdown]
# ### Save as new file

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as color_maps 

three_classes = sugar_pix

w=real_sugar.width
h=real_sugar.height

for i in range(w):
    for j in range(h):
        if rice_pix[j][i] == 1:
            three_classes[j][i] = 2
fig=plt.figure()
fig.set_size_inches(16, 5.5)
fig.add_subplot(1, 2, 1)
plt.imshow(three_classes)
plt.title("Ground-truth")

fig.add_subplot(1, 2, 2)
plt.imshow(rice_pix)
plt.title("Detected area")
# Out:
# Text(0.5, 1.0, 'Detected area')

# %%
import random

#list of (lat,lon)
sugarcane_points = []
rice_points = []
other_points = []


sugarcane_ji = []
rice_ji = []
other_ji = []

labels = []
#n_sample = 5
count = 0

print("start_sampling n=",(len(s2_dataset.latitude.data)*len(s2_dataset.longitude.data)))
print("area =", (len(s2_dataset.latitude.data)*len(s2_dataset.longitude.data))*100/1000000)
#while len(sugarcane_points) < n_sample*safety_factor or len(rice_points) < n_sample*safety_factor :
for j in range(len(s2_dataset.latitude.data)) : 
    for i in range(len(s2_dataset.longitude.data)) : 
        lat = s2_dataset.latitude.data[j]
        lon = s2_dataset.longitude.data[i]


        #if in_polygon(lat, lon, sugarcane_area):
        if rice_pix[j][i]==0 and sugar_pix[j][i]==1:
            #print(lat, lon)
            #print("sugar")
            sugarcane_points.append((lat,lon))
            sugarcane_ji.append((j,i))
            #label.append(1)
        #elif in_polygon(lat, lon, rice_area):
        
        #elif rice_pix[j][i]==1 and sugar_pix[j][i]==0:
        elif rice_pix[j][i]==1:
            #print(lat, lon)
            #print("rice")
            rice_points.append((lat,lon))
            rice_ji.append((j,i))
            #label.append(2)
            
        else: 
            other_points.append((lat,lon))
            other_ji.append((j,i))
            #label.append(0)
        count += 1
        
        if count<10 or count%10000 == 0:
            print("iteration:", count, "sugarcane_points:", len(sugarcane_points), "rice_points:", len(rice_points), "other_points:", len(other_points))
# Out:
# start_sampling n= 768152
# area = 76.8152
# iteration: 1 sugarcane_points: 1 rice_points: 0 other_points: 0
# iteration: 2 sugarcane_points: 2 rice_points: 0 other_points: 0
# iteration: 3 sugarcane_points: 3 rice_points: 0 other_points: 0
# iteration: 4 sugarcane_points: 4 rice_points: 0 other_points: 0
# iteration: 5 sugarcane_points: 5 rice_points: 0 other_points: 0
# iteration: 6 sugarcane_points: 6 rice_points: 0 other_points: 0
# iteration: 7 sugarcane_points: 7 rice_points: 0 other_points: 0
# iteration: 8 sugarcane_points: 8 rice_points: 0 other_points: 0
# iteration: 9 sugarcane_points: 9 rice_points: 0 other_points: 0
# iteration: 10000 sugarcane_points: 6806 rice_points: 843 other_points: 2351
# iteration: 20000 sugarcane_points: 14360 rice_points: 1503 other_points: 4137
# iteration: 30000 sugarcane_points: 21240 rice_points: 2784 other_points: 5976
# iteration: 40000 sugarcane_points: 27470 rice_points: 4928 other_points: 7602
# iteration: 50000 sugarcane_points: 33264 rice_points: 7877 other_points: 8859
# iteration: 60000 sugarcane_points: 38837 rice_points: 11307 other_points: 9856
# iteration: 70000 sugarcane_points: 44568 rice_points: 14434 other_points: 10998
# iteration: 80000 sugarcane_points: 49497 rice_points: 18130 other_points: 12373
# iteration: 90000 sugarcane_points: 53716 rice_points: 22403 other_points: 13881
# iteration: 100000 sugarcane_points: 56925 rice_points: 27848 other_points: 15227
# iteration: 110000 sugarcane_points: 59234 rice_points: 33896 other_points: 16870
# iteration: 120000 sugarcane_points: 60473 rice_points: 40198 other_points: 19329
# iteration: 130000 sugarcane_points: 61162 rice_points: 46350 other_points: 22488
# iteration: 140000 sugarcane_points: 61963 rice_points: 53118 other_points: 24919
# iteration: 150000 sugarcane_points: 63097 rice_points: 60730 other_points: 26173
# iteration: 160000 sugarcane_points: 64513 rice_points: 68260 other_points: 27227
# iteration: 170000 sugarcane_points: 65679 rice_points: 75762 other_points: 28559
# iteration: 180000 sugarcane_points: 66775 rice_points: 82989 other_points: 30236
# iteration: 190000 sugarcane_points: 67720 rice_points: 90561 other_points: 31719
# iteration: 200000 sugarcane_points: 68873 rice_points: 97885 other_points: 33242
# iteration: 210000 sugarcane_points: 69626 rice_points: 105122 other_points: 35252
# iteration: 220000 sugarcane_points: 70211 rice_points: 112825 other_points: 36964
# iteration: 230000 sugarcane_points: 70734 rice_points: 120946 other_points: 38320
# iteration: 240000 sugarcane_points: 71331 rice_points: 129501 other_points: 39168
# iteration: 250000 sugarcane_points: 71664 rice_points: 138156 other_points: 40180
# iteration: 260000 sugarcane_points: 71806 rice_points: 146678 other_points: 41516
# iteration: 270000 sugarcane_points: 71958 rice_points: 155075 other_points: 42967
# iteration: 280000 sugarcane_points: 72092 rice_points: 162832 other_points: 45076
# iteration: 290000 sugarcane_points: 72622 rice_points: 169928 other_points: 47450
# iteration: 300000 sugarcane_points: 73375 rice_points: 176586 other_points: 50039
# iteration: 310000 sugarcane_points: 74960 rice_points: 182502 other_points: 52538
# iteration: 320000 sugarcane_points: 76705 rice_points: 187527 other_points: 55768
# iteration: 330000 sugarcane_points: 78472 rice_points: 192186 other_points: 59342
# iteration: 340000 sugarcane_points: 80179 rice_points: 196926 other_points: 62895
# iteration: 350000 sugarcane_points: 81383 rice_points: 201944 other_points: 66673
# iteration: 360000 sugarcane_points: 82572 rice_points: 207070 other_points: 70358
# iteration: 370000 sugarcane_points: 83682 rice_points: 212341 other_points: 73977
# iteration: 380000 sugarcane_points: 84812 rice_points: 217322 other_points: 77866
# iteration: 390000 sugarcane_points: 86155 rice_points: 221568 other_points: 82277
# iteration: 400000 sugarcane_points: 87673 rice_points: 225645 other_points: 86682
# iteration: 410000 sugarcane_points: 89920 rice_points: 228969 other_points: 91111
# iteration: 420000 sugarcane_points: 91607 rice_points: 233300 other_points: 95093
# iteration: 430000 sugarcane_points: 92721 rice_points: 237925 other_points: 99354
# iteration: 440000 sugarcane_points: 93616 rice_points: 242815 other_points: 103569
# iteration: 450000 sugarcane_points: 94388 rice_points: 248284 other_points: 107328
# iteration: 460000 sugarcane_points: 94846 rice_points: 254471 other_points: 110683
# iteration: 470000 sugarcane_points: 95118 rice_points: 261079 other_points: 113803
# iteration: 480000 sugarcane_points: 95232 rice_points: 267922 other_points: 116846
# iteration: 490000 sugarcane_points: 95344 rice_points: 275361 other_points: 119295
# iteration: 500000 sugarcane_points: 95587 rice_points: 282170 other_points: 122243
# iteration: 510000 sugarcane_points: 95998 rice_points: 288796 other_points: 125206
# iteration: 520000 sugarcane_points: 96484 rice_points: 295371 other_points: 128145
# iteration: 530000 sugarcane_points: 97343 rice_points: 301362 other_points: 131295
# iteration: 540000 sugarcane_points: 98605 rice_points: 307143 other_points: 134252
# iteration: 550000 sugarcane_points: 100447 rice_points: 312138 other_points: 137415
# iteration: 560000 sugarcane_points: 102622 rice_points: 317155 other_points: 140223
# iteration: 570000 sugarcane_points: 104640 rice_points: 322437 other_points: 142923
# iteration: 580000 sugarcane_points: 107295 rice_points: 327696 other_points: 145009
# iteration: 590000 sugarcane_points: 110333 rice_points: 333085 other_points: 146582
# iteration: 600000 sugarcane_points: 113214 rice_points: 338559 other_points: 148227
# iteration: 610000 sugarcane_points: 115748 rice_points: 344413 other_points: 149839
# iteration: 620000 sugarcane_points: 118059 rice_points: 350040 other_points: 151901
# iteration: 630000 sugarcane_points: 120479 rice_points: 355577 other_points: 153944
# iteration: 640000 sugarcane_points: 123615 rice_points: 360438 other_points: 155947
# iteration: 650000 sugarcane_points: 126891 rice_points: 365375 other_points: 157734
# iteration: 660000 sugarcane_points: 130719 rice_points: 369677 other_points: 159604
# iteration: 670000 sugarcane_points: 135168 rice_points: 372886 other_points: 161946
# iteration: 680000 sugarcane_points: 139551 rice_points: 375207 other_points: 165242
# iteration: 690000 sugarcane_points: 143630 rice_points: 376855 other_points: 169515
# iteration: 700000 sugarcane_points: 148925 rice_points: 378046 other_points: 173029
# iteration: 710000 sugarcane_points: 154578 rice_points: 378874 other_points: 176548
# iteration: 720000 sugarcane_points: 160135 rice_points: 379441 other_points: 180424
# iteration: 730000 sugarcane_points: 165505 rice_points: 379824 other_points: 184671
# iteration: 740000 sugarcane_points: 170841 rice_points: 380248 other_points: 188911
# iteration: 750000 sugarcane_points: 176602 rice_points: 380733 other_points: 192665
# iteration: 760000 sugarcane_points: 182129 rice_points: 381570 other_points: 196301

# %% [markdown]
# ## 4. get NDVI value from (2) using locations from (3)
#
#  $$ {NDVI} = \frac{(X_{NIR}-X_{Red})}{(X_{NIR}+X_{Red})}$$

# %%
tmp_ndvi = ((s2_dataset['nir'].values - s2_dataset['red'].values).astype(np.double)/
                          (s2_dataset['nir'].values + s2_dataset['red'].values + .0001).astype(np.double))

tmp_ndwi =  ((s2_dataset['green'].values - s2_dataset['nir'].values).astype(np.double)/
                  (s2_dataset['green'].values + s2_dataset['nir'].values + .0001).astype(np.double))

# %%
#s2_dataset['ndvi'] = tmp_ndvi
s2_dataset= s2_dataset.assign(ndvi=lambda x: x.nir-x.red/x.nir+x.red+.0001)
s2_dataset= s2_dataset.assign(ndwi=lambda x: x.green-x.nir/x.green+x.nir+.0001)

# %%
s2_dataset
# Out:
# <xarray.Dataset>
# Dimensions:     (latitude: 812, longitude: 946, time: 155)
# Coordinates:
#   * time        (time) datetime64[ns] 2019-05-05T04:03:48.860000 ... 2021-05-29T04:03:41.640000
#   * latitude    (latitude) float64 16.56 16.56 16.56 16.56 ... 16.49 16.49 16.49
#   * longitude   (longitude) float64 99.69 99.69 99.69 ... 99.78 99.78 99.78
# Data variables:
#     coastal     (time, latitude, longitude) int16 780 780 780 ... 13282 13282
#     blue        (time, latitude, longitude) int16 1020 1010 963 ... 13512 13288
#     green       (time, latitude, longitude) int16 1482 1488 1428 ... 12536 12176
#     red         (time, latitude, longitude) int16 1502 1494 1446 ... 11832 11736
#     nir         (time, latitude, longitude) int16 3544 3572 3686 ... 10928 10672
#     narrow_nir  (time, latitude, longitude) int16 3908 3908 4048 ... 11405 11405
#     AOT         (time, latitude, longitude) int16 456 456 456 ... 204 204 204
#     pixel_qa    (time, latitude, longitude) int16 5 5 5 5 4 4 4 ... 9 9 9 9 9 9
#     ndvi        (time, latitude, longitude) float64 5.046e+03 ... 2.241e+04
#     ndwi        (time, latitude, longitude) float64 5.024e+03 ... 2.285e+04
# Attributes:
#     crs:      EPSG:4326

# %%
#filter only rows that has number of zero-value less than 10%

def filter_row(all_points, max_n_sample):
    week_year_array = None
    tmp_array = None
    location = None
    count = 0
    for (lat,lon) in all_points:
        count+=1
        
        if count % 1000==0:
            print("count:",count)
        pixel_mosaic = s2_dataset.sel(latitude=lat, longitude=lon)
        pixel_mosaic
        '''
        tmp_ndvi = ((pixel_mosaic['nir'].values - pixel_mosaic['red'].values).astype(np.double)/
                          (pixel_mosaic['nir'].values + pixel_mosaic['red'].values + .0001).astype(np.double))

        tmp_ndwi =  ((pixel_mosaic['green'].values - pixel_mosaic['nir'].values).astype(np.double)/
                          (pixel_mosaic['green'].values + pixel_mosaic['nir'].values + .0001).astype(np.double))
        '''
        tmp_ndvi = pixel_mosaic['ndvi'].values.astype(np.double)
        tmp_ndwi = pixel_mosaic['ndwi'].values.astype(np.double)
        R = pixel_mosaic['red'].values.astype(np.double)
        G = pixel_mosaic['green'].values.astype(np.double)
        B = pixel_mosaic['blue'].values.astype(np.double)
        nir = pixel_mosaic['nir'].values.astype(np.double)
        narrow_nir = pixel_mosaic['narrow_nir'].values.astype(np.double)
        
        tmp_df = pd.DataFrame({'timestamp': pixel_mosaic['time'].values, 
                               'ndvi': tmp_ndvi,
                              'ndwi': tmp_ndwi,
                              'red': R,
                              'green': G,
                              'blue': B,
                              'nir': nir, 
                              'narrow_nir': narrow_nir, })
        
        tmp_df['week_year'] = tmp_df['timestamp'].dt.strftime("%Y-%U")
        tmp_df = tmp_df[['week_year', 'ndvi', 'ndwi', 'red', 'green', 'blue', 'nir', 'narrow_nir']].groupby('week_year').max()
        tmp_df = tmp_df.reset_index()
        
        if week_year_array is None:
            week_year_array = tmp_df['week_year'].to_numpy()
        
        '''
        #SMOOTHING WITH RMMEH FUNCTION
        tmp_df['smooth_ndvi'] = rmmeh(tmp_df['ndvi'], median_window=7)
        tmp_df['smooth_ndwi'] = rmmeh(tmp_df['ndwi'], median_window=7)
        tmp_df['smooth_red'] = rmmeh(tmp_df['red'], median_window=7)
        tmp_df['smooth_green'] = rmmeh(tmp_df['green'], median_window=7)
        tmp_df['smooth_blue'] = rmmeh(tmp_df['blue'], median_window=7)
        tmp_df['smooth_nir'] = rmmeh(tmp_df['nir'], median_window=7)
        tmp_df['smooth_narrow_nir'] = rmmeh(tmp_df['narrow_nir'], median_window=7)
        '''
        
        n_snapshot = len(week_year_array)
        
        #print(tmp_df['smooth_ndvi'].to_numpy())
        
        #if number of zero-value > 10% then skip this row
        #if (tmp_df['smooth_ndvi'] == 0).sum() > n_snapshot*0.1:
        #    continue
        
        '''
        if tmp_array is None:
            tmp_array = np.array([[tmp_df['smooth_ndvi'].to_numpy(), 
                                  tmp_df['smooth_ndwi'].to_numpy(), 
                                  tmp_df['smooth_red'].to_numpy(), 
                                  tmp_df['smooth_green'].to_numpy(), 
                                  tmp_df['smooth_blue'].to_numpy(), 
                                  tmp_df['smooth_nir'].to_numpy(), 
                                  tmp_df['smooth_narrow_nir'].to_numpy()
                                 ]]
                                )
            #print("TEST")
            #print(tmp_array.shape)
            location = np.array([[lat,lon]])
            
        #elif len(tmp_array) < max_n_sample:
        else:
            tmp_array = np.append(tmp_array,
                                   np.array([[tmp_df['smooth_ndvi'].to_numpy(),
                                  tmp_df['smooth_ndwi'].to_numpy(), 
                                  tmp_df['smooth_red'].to_numpy(), 
                                  tmp_df['smooth_green'].to_numpy(), 
                                  tmp_df['smooth_blue'].to_numpy(), 
                                  tmp_df['smooth_nir'].to_numpy(), 
                                  tmp_df['smooth_narrow_nir'].to_numpy()
                                 ]]), 
                                   axis=0)
                                 
            location = np.append(location,
                                 np.array([[lat,lon]]),
                                 axis=0)
        '''
            
        if tmp_array is None:
            tmp_array = np.array([[tmp_df['ndvi'].to_numpy(), 
                                  tmp_df['ndwi'].to_numpy(), 
                                  tmp_df['red'].to_numpy(), 
                                  tmp_df['green'].to_numpy(), 
                                  tmp_df['blue'].to_numpy(), 
                                  tmp_df['nir'].to_numpy(), 
                                  tmp_df['narrow_nir'].to_numpy()
                                 ]]
                                )
            #print("TEST")
            #print(tmp_array.shape)
            location = np.array([[lat,lon]])
            
        #elif len(tmp_array) < max_n_sample:
        else:
            tmp_array = np.append(tmp_array,
                                   np.array([[tmp_df['ndvi'].to_numpy(),
                                  tmp_df['ndwi'].to_numpy(), 
                                  tmp_df['red'].to_numpy(), 
                                  tmp_df['green'].to_numpy(), 
                                  tmp_df['blue'].to_numpy(), 
                                  tmp_df['nir'].to_numpy(), 
                                  tmp_df['narrow_nir'].to_numpy()
                                 ]]), 
                                   axis=0)
                                 
            location = np.append(location,
                                 np.array([[lat,lon]]),
                                 axis=0)
    return (week_year_array, location ,tmp_array)

# %%
print("Sugar")
(week_year_array, sugar_location ,sugar_data) = filter_row(sugarcane_points, n_sample)
print("Rice")
(week_year_array, rice_location ,rice_data) = filter_row(rice_points, n_sample)
print("Other")
(week_year_array, other_location ,other_data) = filter_row(other_points, n_sample)
# Out:
# Sugar
# count: 1000
# count: 2000
# count: 3000
# count: 4000
# count: 5000
# count: 6000
# count: 7000
# count: 8000
# count: 9000
# count: 10000
# count: 11000
# count: 12000
# count: 13000
# count: 14000
# count: 15000
# count: 16000
# count: 17000
# count: 18000
# count: 19000
# count: 20000
# count: 21000
# count: 22000
# count: 23000
# count: 24000
# count: 25000
# count: 26000
# count: 27000
# count: 28000
# count: 29000
# count: 30000
# count: 31000
# count: 32000
# count: 33000
# count: 34000
# count: 35000
# count: 36000
# count: 37000
# count: 38000
# count: 39000
# count: 40000
# count: 41000
# count: 42000
# count: 43000
# count: 44000
# count: 45000
# count: 46000
# count: 47000
# count: 48000
# count: 49000
# count: 50000
# count: 51000
# count: 52000
# count: 53000
# count: 54000
# count: 55000
# count: 56000
# count: 57000
# count: 58000
# count: 59000
# count: 60000
# count: 61000
# count: 62000
# count: 63000
# count: 64000
# count: 65000
# count: 66000
# count: 67000
# count: 68000
# count: 69000
# count: 70000
# count: 71000
# count: 72000
# count: 73000
# count: 74000
# count: 75000
# count: 76000
# count: 77000
# count: 78000
# count: 79000
# count: 80000
# count: 81000
# count: 82000
# count: 83000
# count: 84000
# count: 85000
# count: 86000
# count: 87000
# count: 88000

# %%
data_array = np.concatenate((sugar_data, rice_data, other_data))
data_array.shape

# %%
all_location = np.concatenate((sugar_location, rice_location, other_location))
all_location.shape

# %%
all_ji = np.array(sugarcane_ji+rice_ji+other_ji)
all_ji.shape

# %%
labels = []
for x in range(0, len(sugar_location)+len(rice_location)+len(other_location)):
    if x < len(sugar_location):
        labels.append(1)
    elif x < len(sugar_location)+len(rice_location):
        labels.append(2)
    else:
        labels.append(0)
        

labels = np.array(labels)
len(labels)

# %%
len(week_year_array)

# %% [markdown]
# ## 5. Sampling 50 rows from sugarcane data and plot

# %% [raw]
# %matplotlib inline
# plt.style.use('seaborn-whitegrid')
#
# samp_idx = np.random.randint(n_sample, size=50)
#
# fig = plt.figure()
# fig.set_size_inches(18, 3)
# ax = plt.axes()
# for idx in samp_idx:
#     ax.plot(week_year_array, data_array[idx,0,:], color='grey');
#
# plt.xticks(rotation=70, size=7)
# plt.show()

# %% [markdown]
# ## 6. Export numpy array

# %%
#Save to NPY format
np.savez("testSetRasterKPP2.npz", x=data_array, y=labels, location=all_location, position=all_ji, weeks = week_year_array)
